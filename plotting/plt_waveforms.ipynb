# %%
from ROOT import TFile, TCanvas, TPad
from ROOT import TCanvas, TGraph
from ROOT import gROOT
from math import sin
from array import array

# %%
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

# %%
cal_file = TFile('/home/iwsatlas1/mgabriel/workspace/Ploting/PhD_Thesis/Calibration/Data/Run-401141-Int000.root', 'open')

# %%
calwf = cal_file.Get('FWD1-INT')

# %%
# Canvases and pads:
multi = 200
can = TCanvas( 'can', 'Penis', 4*multi, 3*multi )
can.Divide(1,2)

pad = can.cd(1)
pad.SetRightMargin(0.1)
# pad.SetFillColor(42)
calwf.Draw()
pad2 = can.cd(2)
pad2.SetFillColor(42)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: can

# %%
from ROOT import gROOT 
gROOT.GetListOfCanvases().Draw()
